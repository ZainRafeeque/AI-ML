# %%
#1. Create a pandas DataFrame from the following dictionary and display it: data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35], 'City': ['New York', 'Paris', 'London']} df = 
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35],
        'City': ['NewYork', 'Paris', 'London']}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age     City
# 0    Alice   25  NewYork
# 1      Bob   30    Paris
# 2  Charlie   35   London

# %%
#2. Load a CSV file named data.csv into a DataFrame.df = ?
df = pd.read_csv('customers-100.csv')
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
# 3. Display the first 10 rows of a DataFrame.result = ?
result = df.head(10)
print(result)
result=pd.DataFrame(result)
# Out:
#    Index      Customer Id First Name  Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1      2  1Ef7b82A4CAAD10    Preston     Lozano
# 2      3  6F94879bDAfE5a6        Roy      Berry
# 3      4  5Cef8BFA16c5e3c      Linda      Olsen
# 4      5  053d585Ab6b3159     Joanna     Bender
# 5      6  2d08FB17EE273F4      Aimee      Downs
# 6      7  EA4d384DfDbBf77     Darren       Peck
# 7      8  0e04AFde9f225dE      Brett     Mullen
# 8      9  C2dE4dEEc489ae0     Sheryl     Meyers
# 9     10  8C2811a503C7c5a   Michelle  Gallagher
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
# 5                     Steele Group      Chavezborough
# ...

# %%
#11. Filter rows where the Age column is greater than 30.filtered_df = ?
#Ans Adding a Age column as the data doesnt contain any Age column
result['Age'] = [25,30,35,28,34,40,26,34,25,34]
result.head()
#filtering age greater than 30
filtered_df = result[result['Age'] > 30]
print(filtered_df)
# Out:
#    Index      Customer Id First Name  Last Name                       Company  \
# 2      3  6F94879bDAfE5a6        Roy      Berry                 Murillo-Perry
# 4      5  053d585Ab6b3159     Joanna     Bender      Martin, Lang and Andrade
# 5      6  2d08FB17EE273F4      Aimee      Downs                  Steele Group
# 7      8  0e04AFde9f225dE      Brett     Mullen  Sanford, Davenport and Giles
# 9     10  8C2811a503C7c5a   Michelle  Gallagher                  Beck-Hendrix
#
#              City                     Country                 Phone 1  \
# 2   Isabelborough         Antigua and Barbuda         +1-539-402-0259
# 4  West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
# 5   Chavezborough      Bosnia and Herzegovina     (283)437-3886x88321
# 7         Kimport                    Bulgaria    001-583-352-7197x297
# 9      Elaineberg                 Timor-Leste        739.218.2516x459
#
#                  Phone 2                    Email Subscription Date  \
# ...

# %%
#12. Add a new column Age_Group to classify Age as 'Young' (Age <= 30) or 'Old' (Age > 30). df['Age_Group'] = ?
#ANS
result['Age_Group'] = result['Age'].apply(lambda x: 'Young' if x <= 30 else 'Old')
result.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
#13. Sort the DataFrame by the Age column in descending order.sorted_df = ?
#ans
sorted_result = result.sort_values(by='Age', ascending=False)
print(sorted_result)
# Out:
#    Index      Customer Id First Name  Last Name  \
# 5      6  2d08FB17EE273F4      Aimee      Downs
# 2      3  6F94879bDAfE5a6        Roy      Berry
# 4      5  053d585Ab6b3159     Joanna     Bender
# 7      8  0e04AFde9f225dE      Brett     Mullen
# 9     10  8C2811a503C7c5a   Michelle  Gallagher
# 1      2  1Ef7b82A4CAAD10    Preston     Lozano
# 3      4  5Cef8BFA16c5e3c      Linda      Olsen
# 6      7  EA4d384DfDbBf77     Darren       Peck
# 0      1  DD37Cf93aecA6Dc     Sheryl     Baxter
# 8      9  C2dE4dEEc489ae0     Sheryl     Meyers
#
#                            Company               City  \
# 5                     Steele Group      Chavezborough
# 2                    Murillo-Perry      Isabelborough
# 4         Martin, Lang and Andrade     West Priscilla
# 7     Sanford, Davenport and Giles            Kimport
# 9                     Beck-Hendrix         Elaineberg
# 1                      Vega-Gentry  East Jimmychester
# ...

# %%
import pandas as pd

start_date = '2023-11-01'
end_date = '2023-11-10'

date_range = pd.date_range(start=start_date, end=end_date)
date_list = date_range.tolist()

print(date_list)
# Out:
# [Timestamp('2023-11-01 00:00:00'), Timestamp('2023-11-02 00:00:00'), Timestamp('2023-11-03 00:00:00'), Timestamp('2023-11-04 00:00:00'), Timestamp('2023-11-05 00:00:00'), Timestamp('2023-11-06 00:00:00'), Timestamp('2023-11-07 00:00:00'), Timestamp('2023-11-08 00:00:00'), Timestamp('2023-11-09 00:00:00'), Timestamp('2023-11-10 00:00:00')]

# %%
#21. Convert a column date with string values like "2023-01-01" into pandas datetime objects.df['date'] = ?
#Ans
result['date_of_join']=date_list
result['date_of_join'] = pd.to_datetime(date_list)
result['date_of_join'] = pd.to_datetime(result['date_of_join'])
result.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
#Extract the year, month, and day from the date column and add them as new columns.df['year'] = ?df['month'] = ?df['day'] = ?
#ans
result['year'] = result['date_of_join'].dt.year
result['month'] = result['date_of_join'].dt.month
result['day'] = result['date_of_join'].dt.day
result.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
# 15. Find the unique values in the City column.unique_cities = ?
unique_cities = result['City'].unique()
unique_cities
# Out:
# array(['East Leonard', 'East Jimmychester', 'Isabelborough', 'Bensonview',
#        'West Priscilla', 'Chavezborough', 'Lake Ana', 'Kimport',
#        'Robersonstad', 'Elaineberg'], dtype=object)

# %%
result['sales']=[500,600,300,400,350,250,350,200,600,700]
result
# Out:
#    Index      Customer Id First Name  Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1      2  1Ef7b82A4CAAD10    Preston     Lozano
# 2      3  6F94879bDAfE5a6        Roy      Berry
# 3      4  5Cef8BFA16c5e3c      Linda      Olsen
# 4      5  053d585Ab6b3159     Joanna     Bender
# 5      6  2d08FB17EE273F4      Aimee      Downs
# 6      7  EA4d384DfDbBf77     Darren       Peck
# 7      8  0e04AFde9f225dE      Brett     Mullen
# 8      9  C2dE4dEEc489ae0     Sheryl     Meyers
# 9     10  8C2811a503C7c5a   Michelle  Gallagher
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
# 5                     Steele Group      Chavezborough
# ...

# %%
# 27. Use multiple columns (region, category) to group the data and find the sum of the sales column.grouped = ?
#ans creating column region and category
result['Region']=['East', 'West', 'East', 'West', 'East', 'West', 'East', 'West', 'East', 'West']
result['Category']=['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B', 'A', 'B']
group = result.groupby(['Region', 'Category'])['sales'].sum()
print(group)
# Out:
# Region  Category
# East    A           2100
# West    B           2150
# Name: sales, dtype: int64

# %%
#26.Group the DataFrame by category and calculate the mean of the sales column.grouped = ?
#ans
grouped = result.groupby('Category')['sales'].mean()
print(grouped)
# Out:
# Category
# A    420.0
# B    430.0
# Name: sales, dtype: float64

# %%
# 35. Create a MultiIndex from the columns region and category.df = df.set_index([?, ?]
result1 = result.set_index(['Region', 'Category'])
result1
# Out:
#                  Index      Customer Id First Name  Last Name  \
# Region Category
# East   A             1  DD37Cf93aecA6Dc     Sheryl     Baxter
# West   B             2  1Ef7b82A4CAAD10    Preston     Lozano
# East   A             3  6F94879bDAfE5a6        Roy      Berry
# West   B             4  5Cef8BFA16c5e3c      Linda      Olsen
# East   A             5  053d585Ab6b3159     Joanna     Bender
# West   B             6  2d08FB17EE273F4      Aimee      Downs
# East   A             7  EA4d384DfDbBf77     Darren       Peck
# West   B             8  0e04AFde9f225dE      Brett     Mullen
# East   A             9  C2dE4dEEc489ae0     Sheryl     Meyers
# West   B            10  8C2811a503C7c5a   Michelle  Gallagher
#
#                                          Company               City  \
# Region Category
# East   A                         Rasmussen Group       East Leonard
# West   B                             Vega-Gentry  East Jimmychester
# ...

# %%
#36. Select all rows where the region is "West" from a MultiIndex DataFrame.subset = 
#ans
subset = result1.loc['West']
subset
# Out:
#           Index      Customer Id First Name  Last Name  \
# Category
# B             2  1Ef7b82A4CAAD10    Preston     Lozano
# B             4  5Cef8BFA16c5e3c      Linda      Olsen
# B             6  2d08FB17EE273F4      Aimee      Downs
# B             8  0e04AFde9f225dE      Brett     Mullen
# B            10  8C2811a503C7c5a   Michelle  Gallagher
#
#                                   Company               City  \
# Category
# B                             Vega-Gentry  East Jimmychester
# B         Dominguez, Mcmillan and Donovan         Bensonview
# B                            Steele Group      Chavezborough
# B            Sanford, Davenport and Giles            Kimport
# B                            Beck-Hendrix         Elaineberg
#
#                          Country                 Phone 1  \
# Category
# B                       Djibouti              5153435776
# B             Dominican Republic  001-808-617-6467x12895
# ...

# %%
#17. Concatenate two DataFrames df1 and df2 vertically. result = ?
#ans
result2=pd.concat([result, result1], axis=0)
result2
# Out:
#            Index      Customer Id First Name  Last Name  \
# 0              1  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1              2  1Ef7b82A4CAAD10    Preston     Lozano
# 2              3  6F94879bDAfE5a6        Roy      Berry
# 3              4  5Cef8BFA16c5e3c      Linda      Olsen
# 4              5  053d585Ab6b3159     Joanna     Bender
# 5              6  2d08FB17EE273F4      Aimee      Downs
# 6              7  EA4d384DfDbBf77     Darren       Peck
# 7              8  0e04AFde9f225dE      Brett     Mullen
# 8              9  C2dE4dEEc489ae0     Sheryl     Meyers
# 9             10  8C2811a503C7c5a   Michelle  Gallagher
# (East, A)      1  DD37Cf93aecA6Dc     Sheryl     Baxter
# (West, B)      2  1Ef7b82A4CAAD10    Preston     Lozano
# (East, A)      3  6F94879bDAfE5a6        Roy      Berry
# (West, B)      4  5Cef8BFA16c5e3c      Linda      Olsen
# (East, A)      5  053d585Ab6b3159     Joanna     Bender
# (West, B)      6  2d08FB17EE273F4      Aimee      Downs
# ...

# %%
# 5. Find the shape (number of rows and columns) of the DataFrame.result = ?
#ans
result3 = result.shape
result3
# Out:
# (10, 21)

# %%
# 7. Add a new column Country to the DataFrame with a default value of 'USA'.df['Country'] = ?
#ans
result['Country'] = 'USA'
result
# Out:
#    Index      Customer Id First Name  Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1      2  1Ef7b82A4CAAD10    Preston     Lozano
# 2      3  6F94879bDAfE5a6        Roy      Berry
# 3      4  5Cef8BFA16c5e3c      Linda      Olsen
# 4      5  053d585Ab6b3159     Joanna     Bender
# 5      6  2d08FB17EE273F4      Aimee      Downs
# 6      7  EA4d384DfDbBf77     Darren       Peck
# 7      8  0e04AFde9f225dE      Brett     Mullen
# 8      9  C2dE4dEEc489ae0     Sheryl     Meyers
# 9     10  8C2811a503C7c5a   Michelle  Gallagher
#
#                            Company               City Country  \
# 0                  Rasmussen Group       East Leonard     USA
# 1                      Vega-Gentry  East Jimmychester     USA
# 2                    Murillo-Perry      Isabelborough     USA
# 3  Dominguez, Mcmillan and Donovan         Bensonview     USA
# 4         Martin, Lang and Andrade     West Priscilla     USA
# ...

# %%
#8. Delete the City column from the DataFrame.df = ?
#ans
result3 = result.drop('City', axis=1)
result3
# Out:
#    Index      Customer Id First Name  Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1      2  1Ef7b82A4CAAD10    Preston     Lozano
# 2      3  6F94879bDAfE5a6        Roy      Berry
# 3      4  5Cef8BFA16c5e3c      Linda      Olsen
# 4      5  053d585Ab6b3159     Joanna     Bender
# 5      6  2d08FB17EE273F4      Aimee      Downs
# 6      7  EA4d384DfDbBf77     Darren       Peck
# 7      8  0e04AFde9f225dE      Brett     Mullen
# 8      9  C2dE4dEEc489ae0     Sheryl     Meyers
# 9     10  8C2811a503C7c5a   Michelle  Gallagher
#
#                            Company Country                 Phone 1  \
# 0                  Rasmussen Group     USA            229.077.5154
# 1                      Vega-Gentry     USA              5153435776
# 2                    Murillo-Perry     USA         +1-539-402-0259
# 3  Dominguez, Mcmillan and Donovan     USA  001-808-617-6467x12895
# 4         Martin, Lang and Andrade     USA  001-234-203-0635x76146
# ...

# %%
#9. Rename the column Age to Years.df = ?
#ans
result = result.rename(columns={'Age': 'Years'})
result
# Out:
#    Index      Customer Id First Name  Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1      2  1Ef7b82A4CAAD10    Preston     Lozano
# 2      3  6F94879bDAfE5a6        Roy      Berry
# 3      4  5Cef8BFA16c5e3c      Linda      Olsen
# 4      5  053d585Ab6b3159     Joanna     Bender
# 5      6  2d08FB17EE273F4      Aimee      Downs
# 6      7  EA4d384DfDbBf77     Darren       Peck
# 7      8  0e04AFde9f225dE      Brett     Mullen
# 8      9  C2dE4dEEc489ae0     Sheryl     Meyers
# 9     10  8C2811a503C7c5a   Michelle  Gallagher
#
#                            Company               City Country  \
# 0                  Rasmussen Group       East Leonard     USA
# 1                      Vega-Gentry  East Jimmychester     USA
# 2                    Murillo-Perry      Isabelborough     USA
# 3  Dominguez, Mcmillan and Donovan         Bensonview     USA
# 4         Martin, Lang and Andrade     West Priscilla     USA
# ...

# %%
#10. Save the DataFrame to a new CSV file called output.csv.df.to_csv(?, index=False)
#ans
result.to_csv('output.csv', index=False)
